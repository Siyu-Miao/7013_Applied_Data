# %% [markdown]
# ## API lab
#
# ### Introduction:
#
# While many data sets are provided though downloadable files, some are provided through application programming interface (API) which allows the code to access some data without downloading the entire dataset.
#
# APIs provide sets of functions and procedures that allow accessing the features or data from an application or other service.
#
#
# #### REST API
# REST is essentially a set of useful conventions for structuring a web API. 'Web API' means an API that you interact with over HTTP, making requests to specific URLs, and often getting relevant data back in the response.
#
# ### Uses
# - Scraping real time information - useful for example for accessing travel route info from mapping applications, social media feed. And any other data that being updated in real time or is changing quickly. Another example of this is stock price data. It doesn’t really make sense to regenerate a data set and download it every minute
# - Getting only the desired tables through filtering instead of downloading the entire data sets. Reddit comments are one example. It doesn’t make much sense (plus won't be permitted) to download the entire Reddit database if we want only some information
#
# ### General Terminology
#
# #### Types of requests
# characterize what action we are going to take by referring to the API
#
# - GET: retrieve information (like search results). This is the most common type of request. Using it, we can get the data we are interested in from those that the API is ready to share.
# - POST: adds new data to the server. Using this type of request, you can, for example, add a new item to your inventory.
# - PUT: changes existing information. For example, using this type of request, it would be possible to change the color or value of an existing product.
# - DELETE: deletes existing information
#
# #### Status codes
# briefly describe the result of the call.
#
# - 200 – OK. The request was successful. The answer itself depends on the method used (GET, POST, etc.) and the API specification.
# - 204 – No Content. The server successfully processed the request and did not return any content.
# - 301 – Moved Permanently. The server responds that the requested page (endpoint) has been moved to another address and redirects to this address.
# - 400 – Bad Request. The server cannot process the request because the client-side errors (incorrect request format).
# - 401 – Unauthorized. Occurs when authentication was failed, due to incorrect credentials or even their absence.
# - 403 – Forbidden. Access to the specified resource is denied.
# - 404 – Not Found. The requested resource was not found on the server.
# - 500 – Internal Server Error. Occurs when an unknown error has occurred on the server.
#
# #### Endpoints
# Usually, an Endpoint is a specific address (for example, https://weather-in-london.com/forecast), by referring to which you get access to certain features/data (in this example above – the weather forecast for London). Commonly, the name (address) of the endpoint corresponds to the functionality it provides.

# %% [markdown]
# ### HereMap API
# Provides mapping, location data and routing information services worldwide. Routing info is available for transit, walking, driving, bike modes.

# %%
import pandas as pd
import glob #Unix style pathname pattern expansion
import numpy as np
from dateutil import parser #powerful extensions to datetime; offers a generic date/time string parser
import time
from tqdm import tqdm #Customisable progressbar for iterators
try: #spelling depends on enviroment version 
    import urllib2 as urllib #URL handling module
except ImportError:
    import urllib.request as urllib
import json
import geopandas as gpd
import sys
from IPython.display import clear_output #Clears the output of the current cell receiving output
import requests #the module for making HTTP requests in Python; provides GET funcionality

# %% [markdown]
# #### Request API key by creating free account
#
# https://developer.here.com/sign-up?create=Freemium-Basic&keepState=true&step=account
#
# (We recommend not to put your credit card info, all the API services will work for free without having to put your card)
#
# 1. After signing in, click on 'Start with REST APIs' part. Follow the instructions in the 'Access Manager' to create the app.
# 2. After setting up the app, create the API key in the 'Credentials' section.
#
# Note: For some API services, you may need an additional step to create a 'Project'. Please follow the below instructions to create a project and link your app to it. (not needed for this notebook/assignment)
#
# 1. Open the Projects Manager from the launcher.
# 2. Click Create new project and name the project.
# 3. In the 'Services' section, search for the services you'd like to access with the API. (eg. Maps services)
# 4. Link your app from the "Access Manager" tab to the above project and start using the API services.

# %% [markdown]
# #### Example 1: getting driving time

# %% [markdown]
# #### API endpoint
# https://developer.here.com/documentation/routing-api/8.3.1/dev_guide/topics/send-request.html

# %% [markdown]
# #### Sample request
#
# An API request needs an endpoint link with API key to fetch data. In some cases, you may also need appID and appCode to make a request. When you make a account in a particular API service, you will be asked to create and name your app. When you finish this step, you will be provided with a unique API key together with appID and appCode as a unique identifier for your app.
#
# Please not that various APIs have certain restrictions on their usage. Please make sure to read the the usage terms before making acccount (especially if you are asked to enter your payment info beforehand!)
#
# HereMap API has 250k free requests per month. (And it does not ask for credit card info when you create an account)
#
# Also, please note the below example uses an API key for this lab's demonstration purposes only. Please create your HereMap account and get your unique API key when attempting the lab or homeworks yourself.
#
# retreive a driving route between the two given points

# %%
# enter your api key from HereMap
apiKey = 'bc27E14ltgyOh7tZXeuKEOWSiF-1q51gRkIaiRV3mhE'

lon_pickup, lat_pickup = -73.972136, 40.744301 ##origin: A point in Manhattan (around E 35th street)
lon_dropoff, lat_dropoff = -74.172945, 40.680108 # destination: Newark airport

# %% [markdown]
# #### Routing API info and documentation
# https://developer.here.com/documentation/routing-api/dev_guide/topics/use-cases/calculate-route.html
#
# Note the driving API endpoint is 'https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}', which essentially gives the driving directions from origin to destination together with a summary of the whole trip.
#
# For the above origin-destination lat-longs, the endpoint will look like
#
# 'https://router.hereapi.com/v8/routes?transportMode=car&origin=40.744301,-73.972136&destination=40.680108,-74.172945&return=summary&apikey={}'
#
# Basically, the origin lat-long go in after the 'waypoint0=geo!' field and destination lat-long go in after 'waypoint1=geo!' field. Instead of manually putting these lat-long in the code, the pythonic way to do this is by the 'format' function. Wherever we need to insert variables, we put '{}' in the url and then specify the variables in their respective order of appearing in the url in the 'format' command.

# %%
url = str('https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}'.format(
    lat_pickup, lon_pickup, lat_dropoff, lon_dropoff, apiKey))
print(url)
# Out:
# https://router.hereapi.com/v8/routes?transportMode=car&origin=40.744301,-73.972136&destination=40.680108,-74.172945&return=summary&apikey=bc27E14ltgyOh7tZXeuKEOWSiF-1q51gRkIaiRV3mhE

# %% [markdown]
# Now we'll make a request with the below command

# %%
data = urllib.urlopen(url).read().decode('utf-8')
data = json.loads(data)

# %% [markdown]
# The fetched data gives driving directions together with a summary of the whole trip

# %%
data
# Out:
# {'routes': [{'id': 'd68cfaae-0752-4b16-bcd1-62b8a3530c8e',
#    'sections': [{'id': '12601fb0-903b-4291-81a0-0960a26ba7e6',
#      'type': 'vehicle',
#      'departure': {'time': '2023-10-02T22:57:00-04:00',
#       'place': {'type': 'place',
#        'location': {'lat': 40.7441211, 'lng': -73.9722708},
#        'originalLocation': {'lat': 40.744301, 'lng': -73.9721361}}},
#      'arrival': {'time': '2023-10-02T23:30:20-04:00',
#       'place': {'type': 'place',
#        'location': {'lat': 40.6790562, 'lng': -74.1703941},
#        'originalLocation': {'lat': 40.6801079, 'lng': -74.172945}}},
#      'summary': {'duration': 2000, 'length': 26596, 'baseDuration': 1699},
#      'transport': {'mode': 'car'}}]}]}

# %% [markdown]
# The retrived output contains all information in the 'routes' key, including the travel time ('duration') and travel distance ('length')

# %% [markdown]
# Let's print the time and distance of the whole trip

# %%
# get travel time in seconds
data['routes'][0]['sections'][0]['summary']['duration']
# Out:
# 2000

# %%
# travel distance in meters
data['routes'][0]['sections'][0]['summary']['length']
# Out:
# 26596

# %% [markdown]
# #### Example 2: getting transit time

# %% [markdown]
# #### API info and documentation
# https://developer.here.com/documentation/public-transit/dev_guide/quick-start.html

# %%
lon_pickup, lat_pickup = -73.972136, 40.744301
lon_dropoff, lat_dropoff = -74.008704, 40.708592

# API endpoint link
url = str('https://transit.router.hereapi.com/v8/routes?apiKey={}&origin={},{}&destination={},{}'.format(apiKey, lat_pickup, lon_pickup, 
                                                                                                        lat_dropoff, lon_dropoff))

data = urllib.urlopen(url).read().decode('utf-8')
data = json.loads(data)
data
# Out:
# {'routes': [{'id': 'R0',
#    'sections': [{'id': 'R0-S0',
#      'type': 'pedestrian',
#      'departure': {'time': '2023-10-02T23:01:00-04:00',
#       'place': {'type': 'place',
#        'location': {'lat': 40.744301, 'lng': -73.972136}}},
#      'arrival': {'time': '2023-10-02T23:18:00-04:00',
#       'place': {'name': '33 St',
#        'type': 'station',
#        'location': {'lat': 40.746081, 'lng': -73.982076},
#        'id': '717080436'}},
#      'transport': {'mode': 'pedestrian'}},
#     {'id': 'R0-S1',
#      'type': 'transit',
#      'departure': {'time': '2023-10-02T23:18:00-04:00',
#       'place': {'name': '33 St',
#        'type': 'station',
#        'location': {'lat': 40.746081, 'lng': -73.982076},
#        'id': '717080436'}},
#      'arrival': {'time': '2023-10-02T23:22:00-04:00',
#       'place': {'name': '14 St-Union Sq',
#        'type': 'station',
#        'location': {'lat': 40.734673, 'lng': -73.989951},
#        'id': '717080445'}},
#      'transport': {'mode': 'subway',
#       'name': '6',
#       'category': 'Subway, Metro',
#       'color': '#00933C',
#       'headsign': 'Brooklyn Bridge-City Hall',
#       'shortName': '6',
#       'longName': 'Lexington Avenue Local'},
#      'agency': {'id': '10327_9f822fe',
#       'name': 'MTA New York City Transit',
#       'website': 'http://www.mta.info'}},
#     {'id': 'R0-S2',
#      'type': 'transit',
#      'departure': {'time': '2023-10-02T23:24:00-04:00',
#       'place': {'name': '14 St-Union Sq',
#        'type': 'station',
#        'location': {'lat': 40.734673, 'lng': -73.989951},
#        'id': '717080445'},
#       'delay': 360},
#      'arrival': {'time': '2023-10-02T23:30:00-04:00',
#       'place': {'name': 'Fulton St',
#        'type': 'station',
#        'location': {'lat': 40.710368, 'lng': -74.009509},
#        'id': '717080322'},
#       'delay': 360},
#      'transport': {'mode': 'subway',
#       'name': '4',
#       'category': 'Subway, Metro',
#       'color': '#00933C',
#       'headsign': 'New Lots Av',
#       'shortName': '4',
#       'longName': 'Lexington Avenue Express'},
#      'agency': {'id': '10327_9f822fe',
#       'name': 'MTA New York City Transit',
#       'website': 'http://www.mta.info'}},
#     {'id': 'R0-S3',
#      'type': 'pedestrian',
#      'departure': {'time': '2023-10-02T23:30:00-04:00',
#       'place': {'name': 'Fulton St',
#        'type': 'station',
#        'location': {'lat': 40.710368, 'lng': -74.009509},
#        'id': '717080322'}},
#      'arrival': {'time': '2023-10-02T23:34:00-04:00',
#       'place': {'type': 'place',
#        'location': {'lat': 40.708592, 'lng': -74.008704}}},
#      'transport': {'mode': 'pedestrian'}}]}]}

# %% [markdown]
# Note that retrieved output keys are different from what we obtained in case of driving direction request.
#
# Here all data is present in the 'routes' key with information regarding intermediate stations. If we are interested in overall travel time, we'll need to access the first and last 'routes' and get the difference between the last arrival time and first departure time.
#
# Important: You may get the retrieved repsonse other than above if any transit route is not available from specified origin to destination.
# Invalid responses are 'Timestamp out of validity period' and 'No result found'

# %%
# get travel time - subtract arrival time from last route and departure time from first route

(parser.isoparse(data['routes'][0]['sections'][-1]['arrival']['time']) 
    - parser.isoparse(data['routes'][0]['sections'][0]['departure']['time']))
# Out:
# datetime.timedelta(seconds=1980)

# %%
# convert to minutes

str(parser.isoparse(data['routes'][0]['sections'][-1]['arrival']['time']) 
    - parser.isoparse(data['routes'][0]['sections'][0]['departure']['time']))
# Out:
# '0:33:00'

# %% [markdown]
# Travel time

# %% [markdown]
# ## Now access information for a sample of selected origin-destination points

# %%
# sample points lat-longs

df = pd.read_csv('https://raw.githubusercontent.com/CUSP2020PUI/Data/master/samplePoints.csv')
df.head()
# Out:
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 0           1  -74.174000   40.691831          145   -73.948891    40.745379
# 1           2  -73.831299   40.616745          203   -73.739473    40.657853
# 2           3  -73.847422   40.864474           77   -73.895364    40.666559
# 3           4  -73.976968   40.723752          158   -74.008984    40.735035
# 4           5  -74.188484   40.552659          123   -73.964334    40.599954

# %%
len(df) ##one random point per each zip code
# Out:
# 263

# %% [markdown]
# Function for getting driving time for a dataframe of above type

# %%
def driving(file, apiKey): 
    '''
    Input: the file that contain origin-destination lan/long information; keys from Map
    Output: list of driving times corresponding the input O-D pairs
    '''
    duration_list= []  # list for storing times
    for index, row in tqdm(file.iterrows()): # iterating through all rows of sample points
        lon_pickup = row['lon_pickup']  
        lat_pickup = row['lat_pickup']
        lon_dropoff = row['lon_dropoff']
        lat_dropoff = row['lat_dropoff']
        
        # specifying origin-desination lat-longs in the endpoint and making request
        url = str('https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}'.format(lat_pickup, lon_pickup, lat_dropoff, lon_dropoff, apiKey))
        data = urllib.urlopen(url).read().decode('utf-8')
        data = json.loads(data)
        
        # append travel time to 'duration' list, nan if no travel time retrieved
        try:    
            duration = data['routes'][0]['sections'][0]['summary']['duration']
        except:
            duration = np.nan
            
        duration_list.append(duration)

    return duration_list

# %% [markdown]
# Passing 10 random O-D pairs

# %%
sample = df.sample(10, random_state=2020)
sample.reset_index(drop=True, inplace=True)

sample
# Out:
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 0         110  -74.128342   40.545780          254   -73.858948    40.882157
# 1          51  -73.828264   40.873973           92   -73.828859    40.761102
# 2         166  -73.961764   40.809457          234   -73.990458    40.740337
# 3         207  -73.899353   40.763986          248   -73.872289    40.834165
# 4         195  -74.009178   40.675549           68   -73.999917    40.748428
# 5         251  -74.125348   40.616880          114   -73.997380    40.728340
# 6          71  -73.937966   40.644288          118   -74.132979    40.586555
# 7         139  -73.744234   40.677098          202   -73.949952    40.761900
# 8          76  -73.876821   40.660935          240   -73.881978    40.894599
# 9         165  -73.956825   40.620924          258   -73.855767    40.688721

# %% [markdown]
# Calling the function to get responses from API

# %%
sample['driving_time'] = driving(sample, apiKey)
sample
# Out:
# 10it [00:00, 12.26it/s]
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff  \
# 0         110  -74.128342   40.545780          254   -73.858948    40.882157
# 1          51  -73.828264   40.873973           92   -73.828859    40.761102
# 2         166  -73.961764   40.809457          234   -73.990458    40.740337
# 3         207  -73.899353   40.763986          248   -73.872289    40.834165
# 4         195  -74.009178   40.675549           68   -73.999917    40.748428
# 5         251  -74.125348   40.616880          114   -73.997380    40.728340
# 6          71  -73.937966   40.644288          118   -74.132979    40.586555
# 7         139  -73.744234   40.677098          202   -73.949952    40.761900
# 8          76  -73.876821   40.660935          240   -73.881978    40.894599
# 9         165  -73.956825   40.620924          258   -73.855767    40.688721
#
#    driving_time
# 0          4131
# 1          1157
# 2          1407
# 3          1225
# 4          1163
# 5          1958
# 6          2132
# 7          2253
# 8          2508
# 9          1805

# %% [markdown]
# ### NYC Open data API:
# NYC open data offers API for almost every available data from crime, housing, 311, taxi etc.
# Also its free for the most part and no account needed
#
# https://opendata.cityofnewyork.us/

# %% [markdown]
# #### Example: Endpoint for 2018 taxi data
# https://data.cityofnewyork.us/resource/t29m-gskq.json

# %%
# some parameters to filter the data. We can specify as many parameters as columns in the table.
# reference: https://dev.socrata.com/foundry/data.cityofnewyork.us/t29m-gskq

# extracting info for a specific O-D pair corresponding to near E 35th st as pick up and Newark airport as drop off
# this is around the same pick-up and drop-off location we used to get driving time from HereMap API
parameter = {'pulocationid':162, 'dolocationid':1}

# %% [markdown]
# making API request
#
# 'requests' is another package of making web requests. Highly uselful in the case of REST APIs and we can provide parameters together in one line of code. We'll use the 'get' method to retrieve data

# %%
url =  "https://data.cityofnewyork.us/resource/t29m-gskq.json"
r = requests.get(url = url, params=parameter)
data = r.json()

# %% [markdown]
# fisrt three returned observations

# %%
data[:3]
# Out:
# [{'vendorid': '1',
#   'tpep_pickup_datetime': '2018-02-14T13:10:19.000',
#   'tpep_dropoff_datetime': '2018-02-14T13:53:15.000',
#   'passenger_count': '1',
#   'trip_distance': '17.40',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '1',
#   'fare_amount': '68.5',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '12',
#   'tolls_amount': '10.5',
#   'improvement_surcharge': '0.3',
#   'total_amount': '91.3'},
#  {'vendorid': '2',
#   'tpep_pickup_datetime': '2018-02-14T14:25:43.000',
#   'tpep_dropoff_datetime': '2018-02-14T15:05:18.000',
#   'passenger_count': '2',
#   'trip_distance': '17.40',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '1',
#   'fare_amount': '68',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '0',
#   'tolls_amount': '16.1',
#   'improvement_surcharge': '0.3',
#   'total_amount': '84.4'},
#  {'vendorid': '1',
#   'tpep_pickup_datetime': '2018-02-14T14:38:48.000',
#   'tpep_dropoff_datetime': '2018-02-14T15:36:03.000',
#   'passenger_count': '1',
#   'trip_distance': '21.70',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '2',
#   'fare_amount': '81',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '0',
#   'tolls_amount': '15.49',
#   'improvement_surcharge': '0.3',
#   'total_amount': '96.79'}]

# %% [markdown]
# Note that the returned request contains information reagrding pick up and drop off times, distance covered, fare amount, number of passengers etc. Essentially, it returns all info provided by TLC in any csv file.

# %% [markdown]
# Let's get travel time from first observation

# %%
# travel time in seconds
parser.parse(data[0]['tpep_dropoff_datetime']) - parser.parse(data[0]['tpep_pickup_datetime'])
# Out:
# datetime.timedelta(seconds=2576)

# %% [markdown]
# Note the travel time returned is around 40 minutes compared to around 28 minutes from driving time retrieved from HereMap API before. Also note time can vary based on the pick up times, the above time of 40 min correspond to pick up around 7pm.

# %% [markdown]
# #### get yellow taxi times for O-D pairs as before
#
# #### Note: taxi data can be full of absurd values in terms of travel times/fares/distances. So we need to filter out all noise while we extract.
# #### We'll make the same checks for filtering as we did in the taxi data lab
#
# 1. Get rid of observations with travel time > 1 min and < 100 min
# 2. Speed (distance/time) should be > 2mph and <80mph
# 3. Fare should be < 300 USD and > 2.5 USD
# 4. distance traveled < 100 and > 0.3

# %%
def taxiTime(df):
    
    times = [] # list for storing travel times
    
    for index, row in df.iterrows(): # iterating through all rows of sample points
        
        # specify parameters for making request
        parameters = {'pulocationid':int(row['LocationID']), 'dolocationid':int(row['LocationID2'])}
        
        url =  "https://data.cityofnewyork.us/resource/t29m-gskq.json"
        r = requests.get(url = url, params=parameters)
        data = r.json()
        
        travelTime = []
        
        for obs in data: # iterating through each returned observation for the returned data 
            
            # making sanity checks and appending times to 'traveTime' list
            try:
                time = parser.parse(obs['tpep_dropoff_datetime']) - parser.parse(obs['tpep_pickup_datetime'])
                time = time.total_seconds()
                fare = float(obs['fare_amount'])
                distance = float(obs['trip_distance'])
                speed = distance/(time/3600)

                if (time < 6000 and time > 60 and fare < 200  
                    and fare > 2.5 and fare < 300 and speed < 80  and speed > 2 and distance > 0.3 and 
                    distance < 100):
                    travelTime.append(time)
                    
            except: 
                pass
            
        # now appending the mean of travel times retrieved above to the 'times' list
    
        times.append(np.mean(travelTime))
        
        
    return times

# %%
sample['TLC_avgtime'] = taxiTime(sample)
sample
# Out:
# /Users/siyumiao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/siyumiao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  \
# 109         110  -74.128342   40.545780          254   -73.858948
# 50           51  -73.828264   40.873973           92   -73.828859
# 165         166  -73.961764   40.809457          234   -73.990458
# 206         207  -73.899353   40.763986          248   -73.872289
# 194         195  -74.009178   40.675549           68   -73.999917
# 250         251  -74.125348   40.616880          114   -73.997380
# 70           71  -73.937966   40.644288          118   -74.132979
# 138         139  -73.744234   40.677098          202   -73.949952
# 75           76  -73.876821   40.660935          240   -73.881978
# 164         165  -73.956825   40.620924          258   -73.855767
# 240         241  -73.895620   40.876512          205   -73.763146
# 144         145  -73.948891   40.745379           80   -73.936793
# 224         225  -73.931888   40.688168          111   -73.990235
# 104         103  -74.019073   40.688784          215   -73.790964
# 34           35  -73.910258   40.664003          124   -73.844919
# 245         246  -74.004015   40.753309          197   -73.830924
# 221         222  -73.882413   40.647527          131   -73.776101
# 87           88  -74.011515   40.703358           35   -73.910258
# 162         163  -73.977569   40.764421           78   -73.885522
# 61           62  -73.948789   40.666540          141   -73.959635
# 123         124  -73.844919   40.658248          103   -74.040771
# 93           94  -73.899536   40.858155          204   -74.207826
# 5             6  -74.071771   40.600324          242   -73.850671
# 58           59  -73.894986   40.838550           82   -73.877118
# 158         159  -73.912849   40.818260          263   -73.951010
# 31           32  -73.864901   40.864002          169   -73.905122
# 101         102  -73.875736   40.703546          165   -73.956825
# 25           26  -73.988661   40.630950          150   -73.943629
# 241         242  -73.850671   40.846783           81   -73.836643
# 180         181  -73.981414   40.670374          152   -73.953782
# 242         243  -73.932831   40.857108          192   -73.815229
# 106         107  -73.984052   40.736824          142   -73.981532
# 214         215  -73.790964   40.694428          177   -73.913632
# 35           36  -73.917711   40.700522           33   -73.995250
# 220         221  -74.073704   40.618769          133   -73.976199
# 15           16  -73.773422   40.762738           59   -73.894986
# 103         103  -74.040771   40.698769           48   -73.989845
# 108         109  -74.150890   40.551863           73   -73.807294
# 124         125  -74.007486   40.726290           44   -74.233534
# 256         257  -73.977982   40.653612          156   -74.167235
# 43           44  -74.233534   40.525495           83   -73.892173
# 259         260  -73.906306   40.744235          190   -73.968914
# 23           24  -73.965480   40.801970          250   -73.848641
# 18           19  -73.726655   40.735487          103   -74.045288
# 192         193  -73.941997   40.760314           62   -73.948789
# 247         248  -73.872289   40.834165          231   -74.007880
# 27           28  -73.808729   40.711596          100   -73.988787
# 151         152  -73.953782   40.817975           14   -74.029892
# 115         116  -73.948522   40.827013          122   -73.761137
# 51           52  -73.996724   40.686651          193   -73.941997
#
#      lat_dropoff    FHV_times   SFHV_times  TLC_avgtime
# 109    40.882157          NaN          NaN          NaN
# 50     40.761102  1431.289157  1493.700000  1398.000000
# 165    40.740337  1890.944193  2217.561224  1834.531062
# 206    40.834165  1511.000000          NaN          NaN
# 194    40.748428  1640.843750  1828.200000  2149.000000
# 250    40.728340  2540.142857          NaN          NaN
# 70     40.586555  2023.000000          NaN  3126.000000
# 138    40.761900          NaN          NaN          NaN
# 75     40.894599  2593.000000          NaN  3203.666667
# 164    40.688721  2505.500000  2552.625000  2622.000000
# 240    40.691201  2918.133333          NaN          NaN
# 144    40.715370   868.151151  1086.326241   793.379822
# 224    40.652137  1535.833333  2059.000000          NaN
# 104    40.694428          NaN          NaN          NaN
# 34     40.658248  1262.839196  1479.818182  1435.750000
# 245    40.694542  3028.142857  2856.833333  2608.927711
# 221    40.720655  2319.176471  1905.000000  1703.000000
# 87     40.664003  2415.201550  2459.250000  2744.420000
# 162    40.844960  2227.893939  2637.000000  1990.569892
# 61     40.766948  2815.722222  2655.181818  2914.750000
# 123    40.698769          NaN          NaN          NaN
# 93     40.540334          NaN          NaN          NaN
# 5      40.846783  2674.666667          NaN          NaN
# 58     40.739496  1628.428571  1791.333333          NaN
# 158    40.778766  1243.918033  1373.955224  1234.857143
# 31     40.849058  1050.680000  1323.537634  1674.466667
# 101    40.620924  2779.105263  2654.000000  2252.500000
# 25     40.580473  1810.206704  1952.137500  2114.281250
# 241    40.880935   921.833000  1140.143791  1091.036364
# 180    40.817975  2520.184211  2698.769231  2529.794872
# 242    40.743751  1802.533333  2151.333333          NaN
# 106    40.773633  1443.635000  1625.223404  1216.478478
# 214    40.676644  1852.072993  2142.875000  1930.000000
# 35     40.695798  1742.624852  2008.919463  1345.080645
# 220    40.640590  2027.454545  1940.000000          NaN
# 15     40.838550  1063.000000          NaN          NaN
# 103    40.762253          NaN          NaN          NaN
# 108    40.754109  3936.000000          NaN          NaN
# 124    40.525495  2665.000000          NaN  2847.250000
# 256    40.631308  1752.000000          NaN          NaN
# 43     40.738324          NaN          NaN          NaN
# 259    40.661622  1688.428571          NaN  2238.750000
# 23     40.832102  1728.545455  1962.375000  2015.424242
# 18     40.689860          NaN          NaN          NaN
# 192    40.666540  2261.320000  2377.250000  2230.333333
# 247    40.717773  2501.828571  2750.400000  3477.666667
# 27     40.753513  2320.947368  3306.000000  2395.705263
# 151    40.624835  2592.619048  3011.600000  2543.900000
# 115    40.710639  2858.600000  2362.500000  2046.000000
# 51     40.760314  1782.500000          NaN  1835.000000

# %% [markdown]
# ### Homework - extracredit
#
# 1. Extract 2018/2019 FHV and shared FHV data and compare with taxi times from TLC and driving times from HereMap API for 50 random O-D pairs.
# 2. Using geocoding API from HereMAPs

# %% [markdown]
# ### Retrieving FHV and shared FHV data
#
# #### FHV (for hire vehicles) refers to cars belonging to privately owned companies and entities like Uber, Lyft etc. Shared for hire vehicles (SFHV) trips are where two or more people share the same trip (UberPool etc.)
#
#
# use API endpoint: https://data.cityofnewyork.us/resource/u6nh-b56h.json
#
# for shared FHV, use parameter 'SR_flag': 1 and 0 for non shared FHV

# %% [markdown]
# ### Task 1: get sample request for a single O-D pair for both FHV and shared FHV

# %%
# write parameters here for FHV
parameter = {'pulocationid':162, 'dolocationid':1}

# %%
# code here, get travel time from one observation for above O-D pair

# %%
url = "https://data.cityofnewyork.us/resource/u6nh-b56h.json"
r = requests.get(url = url, params=parameter)
data = r.json()
len(data)
# Out:
# 1000

# %%
data
# Out:
# [{'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-01T01:51:19.000',
#   'dropoff_datetime': '2019-01-01T02:37:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T04:07:00.000',
#   'dropoff_datetime': '2019-01-01T04:42:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T04:01:07.000',
#   'dropoff_datetime': '2019-01-01T04:34:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T04:01:53.000',
#   'dropoff_datetime': '2019-01-01T04:35:10.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-01T04:19:35.000',
#   'dropoff_datetime': '2019-01-01T04:51:40.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T05:11:17.000',
#   'dropoff_datetime': '2019-01-01T05:47:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T05:53:03.000',
#   'dropoff_datetime': '2019-01-01T06:28:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-01T05:30:34.000',
#   'dropoff_datetime': '2019-01-01T05:58:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
#   'pickup_datetime': '2019-01-01T05:24:15.000',
#   'dropoff_datetime': '2019-01-01T06:08:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T06:26:47.000',
#   'dropoff_datetime': '2019-01-01T07:14:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T06:49:03.000',
#   'dropoff_datetime': '2019-01-01T07:18:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T06:53:37.000',
#   'dropoff_datetime': '2019-01-01T07:25:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02715',
#   'pickup_datetime': '2019-01-01T06:24:11.000',
#   'dropoff_datetime': '2019-01-01T07:05:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-01T06:14:26.000',
#   'dropoff_datetime': '2019-01-01T06:56:39.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-01T06:29:20.000',
#   'dropoff_datetime': '2019-01-01T07:05:25.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-01T06:14:08.000',
#   'dropoff_datetime': '2019-01-01T06:50:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-01T06:49:43.000',
#   'dropoff_datetime': '2019-01-01T07:23:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T07:58:48.000',
#   'dropoff_datetime': '2019-01-01T08:27:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T07:10:23.000',
#   'dropoff_datetime': '2019-01-01T07:47:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02715',
#   'pickup_datetime': '2019-01-01T08:22:15.000',
#   'dropoff_datetime': '2019-01-01T08:53:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-01T08:51:22.000',
#   'dropoff_datetime': '2019-01-01T09:18:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-01T08:22:30.000',
#   'dropoff_datetime': '2019-01-01T08:59:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-01T08:41:18.000',
#   'dropoff_datetime': '2019-01-01T09:09:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T09:46:55.000',
#   'dropoff_datetime': '2019-01-01T10:19:07.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T09:39:35.000',
#   'dropoff_datetime': '2019-01-01T10:09:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-01T09:16:28.000',
#   'dropoff_datetime': '2019-01-01T09:45:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-01T09:16:16.000',
#   'dropoff_datetime': '2019-01-01T09:46:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-01T09:27:26.000',
#   'dropoff_datetime': '2019-01-01T10:02:49.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-01T09:38:34.000',
#   'dropoff_datetime': '2019-01-01T10:08:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-01T10:31:39.000',
#   'dropoff_datetime': '2019-01-01T10:59:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T10:59:04.000',
#   'dropoff_datetime': '2019-01-01T11:36:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T10:09:28.000',
#   'dropoff_datetime': '2019-01-01T10:41:40.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T10:53:34.000',
#   'dropoff_datetime': '2019-01-01T11:38:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-01T10:52:47.000',
#   'dropoff_datetime': '2019-01-01T11:28:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '3'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-01T10:47:27.000',
#   'dropoff_datetime': '2019-01-01T11:20:33.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T11:51:50.000',
#   'dropoff_datetime': '2019-01-01T12:24:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T11:32:38.000',
#   'dropoff_datetime': '2019-01-01T12:05:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T11:02:47.000',
#   'dropoff_datetime': '2019-01-01T11:42:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-01T11:31:58.000',
#   'dropoff_datetime': '2019-01-01T12:04:59.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T12:32:18.000',
#   'dropoff_datetime': '2019-01-01T13:08:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T12:52:39.000',
#   'dropoff_datetime': '2019-01-01T13:31:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T12:18:28.000',
#   'dropoff_datetime': '2019-01-01T12:51:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T12:56:19.000',
#   'dropoff_datetime': '2019-01-01T13:39:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-01T12:50:39.000',
#   'dropoff_datetime': '2019-01-01T13:21:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B01964',
#   'pickup_datetime': '2019-01-01T13:12:33.000',
#   'dropoff_datetime': '2019-01-01T13:58:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T13:35:05.000',
#   'dropoff_datetime': '2019-01-01T14:11:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T13:34:51.000',
#   'dropoff_datetime': '2019-01-01T14:08:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T13:33:55.000',
#   'dropoff_datetime': '2019-01-01T14:11:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T13:56:09.000',
#   'dropoff_datetime': '2019-01-01T14:47:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T13:08:56.000',
#   'dropoff_datetime': '2019-01-01T13:42:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-01T13:38:09.000',
#   'dropoff_datetime': '2019-01-01T14:18:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-01T13:43:20.000',
#   'dropoff_datetime': '2019-01-01T14:24:05.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T14:04:07.000',
#   'dropoff_datetime': '2019-01-01T14:50:44.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T14:27:34.000',
#   'dropoff_datetime': '2019-01-01T15:58:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T14:07:52.000',
#   'dropoff_datetime': '2019-01-01T14:40:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-01T14:53:34.000',
#   'dropoff_datetime': '2019-01-01T15:26:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T14:35:42.000',
#   'dropoff_datetime': '2019-01-01T15:19:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T14:00:47.000',
#   'dropoff_datetime': '2019-01-01T14:41:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02715',
#   'pickup_datetime': '2019-01-01T14:20:03.000',
#   'dropoff_datetime': '2019-01-01T14:56:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T14:32:36.000',
#   'dropoff_datetime': '2019-01-01T15:14:33.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-01T14:55:35.000',
#   'dropoff_datetime': '2019-01-01T15:48:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02865',
#   'pickup_datetime': '2019-01-01T14:12:55.000',
#   'dropoff_datetime': '2019-01-01T14:53:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02865',
#   'pickup_datetime': '2019-01-01T14:15:28.000',
#   'dropoff_datetime': '2019-01-01T14:51:40.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-01T14:56:31.000',
#   'dropoff_datetime': '2019-01-01T15:35:40.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-01T15:51:53.000',
#   'dropoff_datetime': '2019-01-01T16:36:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T16:40:41.000',
#   'dropoff_datetime': '2019-01-01T17:20:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T16:11:58.000',
#   'dropoff_datetime': '2019-01-01T17:07:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T16:04:04.000',
#   'dropoff_datetime': '2019-01-01T16:49:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-01T16:13:18.000',
#   'dropoff_datetime': '2019-01-01T17:05:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-01T16:17:20.000',
#   'dropoff_datetime': '2019-01-01T16:52:36.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T16:53:55.000',
#   'dropoff_datetime': '2019-01-01T17:38:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-01T16:13:14.000',
#   'dropoff_datetime': '2019-01-01T17:03:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-01T16:13:16.000',
#   'dropoff_datetime': '2019-01-01T17:02:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-01T16:08:09.000',
#   'dropoff_datetime': '2019-01-01T17:01:36.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-01T16:52:19.000',
#   'dropoff_datetime': '2019-01-01T17:49:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-01T16:43:33.000',
#   'dropoff_datetime': '2019-01-01T17:27:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-01T16:01:04.000',
#   'dropoff_datetime': '2019-01-01T17:00:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-01T17:08:04.000',
#   'dropoff_datetime': '2019-01-01T17:47:56.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-01T17:59:20.000',
#   'dropoff_datetime': '2019-01-01T18:45:29.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-01T17:09:27.000',
#   'dropoff_datetime': '2019-01-01T17:43:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-01T17:34:25.000',
#   'dropoff_datetime': '2019-01-01T18:31:23.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-01T17:39:42.000',
#   'dropoff_datetime': '2019-01-01T18:18:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-01T17:39:55.000',
#   'dropoff_datetime': '2019-01-01T18:25:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-01T18:46:12.000',
#   'dropoff_datetime': '2019-01-01T19:26:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-01T18:05:41.000',
#   'dropoff_datetime': '2019-01-01T18:52:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-01T18:18:29.000',
#   'dropoff_datetime': '2019-01-01T18:55:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-01T19:39:53.000',
#   'dropoff_datetime': '2019-01-01T20:24:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-01T19:38:58.000',
#   'dropoff_datetime': '2019-01-01T20:18:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-01T19:22:50.000',
#   'dropoff_datetime': '2019-01-01T20:01:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-01T19:05:10.000',
#   'dropoff_datetime': '2019-01-01T19:48:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-02T03:34:04.000',
#   'dropoff_datetime': '2019-01-02T04:05:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T04:58:41.000',
#   'dropoff_datetime': '2019-01-02T05:25:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T04:47:12.000',
#   'dropoff_datetime': '2019-01-02T05:22:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-02T04:09:21.000',
#   'dropoff_datetime': '2019-01-02T04:49:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T05:29:32.000',
#   'dropoff_datetime': '2019-01-02T06:19:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02715',
#   'pickup_datetime': '2019-01-02T05:48:43.000',
#   'dropoff_datetime': '2019-01-02T06:13:57.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T05:24:32.000',
#   'dropoff_datetime': '2019-01-02T06:01:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-02T05:53:19.000',
#   'dropoff_datetime': '2019-01-02T06:22:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T05:16:57.000',
#   'dropoff_datetime': '2019-01-02T05:52:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-02T05:41:58.000',
#   'dropoff_datetime': '2019-01-02T06:17:05.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T06:14:06.000',
#   'dropoff_datetime': '2019-01-02T07:08:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T06:06:03.000',
#   'dropoff_datetime': '2019-01-02T06:39:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-02T06:03:45.000',
#   'dropoff_datetime': '2019-01-02T06:48:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-02T06:55:25.000',
#   'dropoff_datetime': '2019-01-02T07:41:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-02T06:58:54.000',
#   'dropoff_datetime': '2019-01-02T07:45:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-02T06:49:10.000',
#   'dropoff_datetime': '2019-01-02T07:36:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-02T06:00:23.000',
#   'dropoff_datetime': '2019-01-02T06:42:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T07:27:30.000',
#   'dropoff_datetime': '2019-01-02T08:15:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T07:03:38.000',
#   'dropoff_datetime': '2019-01-02T07:53:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T07:44:54.000',
#   'dropoff_datetime': '2019-01-02T08:29:36.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-02T07:55:18.000',
#   'dropoff_datetime': '2019-01-02T08:31:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-02T07:41:57.000',
#   'dropoff_datetime': '2019-01-02T08:28:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02870',
#   'pickup_datetime': '2019-01-02T07:14:27.000',
#   'dropoff_datetime': '2019-01-02T08:14:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-02T07:17:16.000',
#   'dropoff_datetime': '2019-01-02T08:09:43.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T08:16:07.000',
#   'dropoff_datetime': '2019-01-02T09:02:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-02T08:50:10.000',
#   'dropoff_datetime': '2019-01-02T09:40:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-02T08:36:17.000',
#   'dropoff_datetime': '2019-01-02T09:31:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-02T08:49:09.000',
#   'dropoff_datetime': '2019-01-02T09:36:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
#   'pickup_datetime': '2019-01-02T08:29:27.000',
#   'dropoff_datetime': '2019-01-02T09:12:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-02T08:07:12.000',
#   'dropoff_datetime': '2019-01-02T08:50:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-02T09:15:59.000',
#   'dropoff_datetime': '2019-01-02T10:04:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T09:32:22.000',
#   'dropoff_datetime': '2019-01-02T10:30:25.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-02T09:15:12.000',
#   'dropoff_datetime': '2019-01-02T10:04:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B01964',
#   'pickup_datetime': '2019-01-02T10:30:36.000',
#   'dropoff_datetime': '2019-01-02T11:22:43.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T10:59:53.000',
#   'dropoff_datetime': '2019-01-02T11:40:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T10:11:41.000',
#   'dropoff_datetime': '2019-01-02T10:49:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-02T10:24:20.000',
#   'dropoff_datetime': '2019-01-02T11:04:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T11:54:21.000',
#   'dropoff_datetime': '2019-01-02T12:36:38.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T11:56:17.000',
#   'dropoff_datetime': '2019-01-02T12:41:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-02T11:20:52.000',
#   'dropoff_datetime': '2019-01-02T11:54:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T12:41:05.000',
#   'dropoff_datetime': '2019-01-02T13:38:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T12:06:19.000',
#   'dropoff_datetime': '2019-01-02T12:49:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T12:33:22.000',
#   'dropoff_datetime': '2019-01-02T13:20:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T12:29:14.000',
#   'dropoff_datetime': '2019-01-02T13:16:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T13:20:15.000',
#   'dropoff_datetime': '2019-01-02T14:02:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '2'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T13:56:27.000',
#   'dropoff_datetime': '2019-01-02T14:45:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T13:56:11.000',
#   'dropoff_datetime': '2019-01-02T14:33:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T13:08:33.000',
#   'dropoff_datetime': '2019-01-02T14:00:40.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T13:37:13.000',
#   'dropoff_datetime': '2019-01-02T14:17:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-02T13:43:04.000',
#   'dropoff_datetime': '2019-01-02T14:40:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T13:37:22.000',
#   'dropoff_datetime': '2019-01-02T14:20:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-02T13:05:28.000',
#   'dropoff_datetime': '2019-01-02T13:55:33.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T14:56:31.000',
#   'dropoff_datetime': '2019-01-02T16:05:50.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '3'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T14:37:27.000',
#   'dropoff_datetime': '2019-01-02T15:33:38.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T14:53:26.000',
#   'dropoff_datetime': '2019-01-02T16:09:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T14:30:40.000',
#   'dropoff_datetime': '2019-01-02T15:22:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T14:26:12.000',
#   'dropoff_datetime': '2019-01-02T15:02:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-02T14:43:51.000',
#   'dropoff_datetime': '2019-01-02T15:35:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-02T14:02:15.000',
#   'dropoff_datetime': '2019-01-02T14:44:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-02T14:27:03.000',
#   'dropoff_datetime': '2019-01-02T15:03:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-02T14:30:18.000',
#   'dropoff_datetime': '2019-01-02T15:15:29.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T14:50:08.000',
#   'dropoff_datetime': '2019-01-02T15:55:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-02T14:00:57.000',
#   'dropoff_datetime': '2019-01-02T14:35:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-02T14:57:08.000',
#   'dropoff_datetime': '2019-01-02T15:51:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T15:58:54.000',
#   'dropoff_datetime': '2019-01-02T17:00:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-02T15:29:02.000',
#   'dropoff_datetime': '2019-01-02T16:18:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-02T15:07:48.000',
#   'dropoff_datetime': '2019-01-02T16:02:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T15:08:04.000',
#   'dropoff_datetime': '2019-01-02T15:59:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T15:40:59.000',
#   'dropoff_datetime': '2019-01-02T16:32:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-02T15:21:29.000',
#   'dropoff_datetime': '2019-01-02T16:14:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T16:01:34.000',
#   'dropoff_datetime': '2019-01-02T16:53:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T16:20:19.000',
#   'dropoff_datetime': '2019-01-02T17:17:57.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-02T16:48:47.000',
#   'dropoff_datetime': '2019-01-02T17:35:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T16:57:31.000',
#   'dropoff_datetime': '2019-01-02T17:41:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-02T16:01:55.000',
#   'dropoff_datetime': '2019-01-02T16:49:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-02T16:16:45.000',
#   'dropoff_datetime': '2019-01-02T17:02:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02870',
#   'pickup_datetime': '2019-01-02T16:07:27.000',
#   'dropoff_datetime': '2019-01-02T16:53:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-02T16:43:27.000',
#   'dropoff_datetime': '2019-01-02T17:44:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T17:30:05.000',
#   'dropoff_datetime': '2019-01-02T18:48:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T17:06:32.000',
#   'dropoff_datetime': '2019-01-02T18:07:35.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T17:01:46.000',
#   'dropoff_datetime': '2019-01-02T18:17:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-02T17:53:48.000',
#   'dropoff_datetime': '2019-01-02T18:57:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-02T17:33:10.000',
#   'dropoff_datetime': '2019-01-02T18:36:43.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-02T17:14:37.000',
#   'dropoff_datetime': '2019-01-02T18:24:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-02T18:07:24.000',
#   'dropoff_datetime': '2019-01-02T18:50:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T18:03:52.000',
#   'dropoff_datetime': '2019-01-02T18:45:49.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-02T18:26:08.000',
#   'dropoff_datetime': '2019-01-02T19:13:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-02T18:40:29.000',
#   'dropoff_datetime': '2019-01-02T19:29:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-02T18:50:10.000',
#   'dropoff_datetime': '2019-01-02T19:31:57.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-02T19:27:00.000',
#   'dropoff_datetime': '2019-01-02T19:55:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-02T19:29:58.000',
#   'dropoff_datetime': '2019-01-02T20:05:33.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T22:08:00.000',
#   'dropoff_datetime': '2019-01-02T23:16:59.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T01:17:23.000',
#   'dropoff_datetime': '2019-01-03T01:51:01.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-03T03:49:59.000',
#   'dropoff_datetime': '2019-01-03T04:22:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-03T04:46:08.000',
#   'dropoff_datetime': '2019-01-03T05:24:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T04:32:54.000',
#   'dropoff_datetime': '2019-01-03T05:08:10.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T05:32:13.000',
#   'dropoff_datetime': '2019-01-03T06:09:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-03T05:43:08.000',
#   'dropoff_datetime': '2019-01-03T06:26:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T05:59:26.000',
#   'dropoff_datetime': '2019-01-03T06:31:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-03T05:33:38.000',
#   'dropoff_datetime': '2019-01-03T06:02:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-03T05:06:59.000',
#   'dropoff_datetime': '2019-01-03T05:41:33.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T06:27:07.000',
#   'dropoff_datetime': '2019-01-03T07:17:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T06:38:45.000',
#   'dropoff_datetime': '2019-01-03T07:16:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T06:39:34.000',
#   'dropoff_datetime': '2019-01-03T07:33:56.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-03T06:13:48.000',
#   'dropoff_datetime': '2019-01-03T06:46:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-03T06:39:57.000',
#   'dropoff_datetime': '2019-01-03T07:29:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-03T06:25:46.000',
#   'dropoff_datetime': '2019-01-03T06:58:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-03T07:14:16.000',
#   'dropoff_datetime': '2019-01-03T08:01:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T08:14:30.000',
#   'dropoff_datetime': '2019-01-03T08:55:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T08:30:08.000',
#   'dropoff_datetime': '2019-01-03T09:20:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-03T08:23:19.000',
#   'dropoff_datetime': '2019-01-03T09:04:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-03T08:25:01.000',
#   'dropoff_datetime': '2019-01-03T09:06:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T09:44:52.000',
#   'dropoff_datetime': '2019-01-03T10:29:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T09:37:43.000',
#   'dropoff_datetime': '2019-01-03T10:21:39.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-03T09:41:50.000',
#   'dropoff_datetime': '2019-01-03T10:26:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T10:31:21.000',
#   'dropoff_datetime': '2019-01-03T11:20:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-03T10:19:04.000',
#   'dropoff_datetime': '2019-01-03T11:06:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-03T11:48:07.000',
#   'dropoff_datetime': '2019-01-03T12:39:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
#   'pickup_datetime': '2019-01-03T11:44:45.000',
#   'dropoff_datetime': '2019-01-03T12:23:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T12:57:55.000',
#   'dropoff_datetime': '2019-01-03T13:36:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T12:32:11.000',
#   'dropoff_datetime': '2019-01-03T13:08:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T12:22:16.000',
#   'dropoff_datetime': '2019-01-03T13:02:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-03T12:38:06.000',
#   'dropoff_datetime': '2019-01-03T13:22:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '4'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T13:56:18.000',
#   'dropoff_datetime': '2019-01-03T14:30:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T13:01:16.000',
#   'dropoff_datetime': '2019-01-03T13:35:57.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T13:16:37.000',
#   'dropoff_datetime': '2019-01-03T13:56:01.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-03T13:22:01.000',
#   'dropoff_datetime': '2019-01-03T13:53:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-03T13:25:34.000',
#   'dropoff_datetime': '2019-01-03T13:55:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-03T13:27:37.000',
#   'dropoff_datetime': '2019-01-03T14:08:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-03T13:04:12.000',
#   'dropoff_datetime': '2019-01-03T13:39:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02395',
#   'pickup_datetime': '2019-01-03T14:49:11.000',
#   'dropoff_datetime': '2019-01-03T15:39:44.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T14:16:16.000',
#   'dropoff_datetime': '2019-01-03T15:19:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T14:17:35.000',
#   'dropoff_datetime': '2019-01-03T14:55:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-03T14:15:34.000',
#   'dropoff_datetime': '2019-01-03T14:55:29.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T14:58:09.000',
#   'dropoff_datetime': '2019-01-03T15:36:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-03T14:52:21.000',
#   'dropoff_datetime': '2019-01-03T15:37:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-03T14:45:07.000',
#   'dropoff_datetime': '2019-01-03T15:38:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-03T14:33:45.000',
#   'dropoff_datetime': '2019-01-03T15:26:50.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
#   'pickup_datetime': '2019-01-03T14:10:17.000',
#   'dropoff_datetime': '2019-01-03T14:57:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-03T14:45:35.000',
#   'dropoff_datetime': '2019-01-03T15:24:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-03T14:56:00.000',
#   'dropoff_datetime': '2019-01-03T15:41:20.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T15:16:34.000',
#   'dropoff_datetime': '2019-01-03T16:01:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-03T15:22:20.000',
#   'dropoff_datetime': '2019-01-03T16:19:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T15:27:40.000',
#   'dropoff_datetime': '2019-01-03T16:10:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T15:05:27.000',
#   'dropoff_datetime': '2019-01-03T16:05:16.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T15:32:46.000',
#   'dropoff_datetime': '2019-01-03T16:25:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-03T15:29:41.000',
#   'dropoff_datetime': '2019-01-03T16:25:08.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-03T15:08:05.000',
#   'dropoff_datetime': '2019-01-03T15:43:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-03T15:12:55.000',
#   'dropoff_datetime': '2019-01-03T16:01:05.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T16:03:01.000',
#   'dropoff_datetime': '2019-01-03T16:56:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T16:09:57.000',
#   'dropoff_datetime': '2019-01-03T17:07:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-03T16:17:25.000',
#   'dropoff_datetime': '2019-01-03T17:02:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02800',
#   'pickup_datetime': '2019-01-03T16:58:20.000',
#   'dropoff_datetime': '2019-01-03T17:48:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-03T16:12:58.000',
#   'dropoff_datetime': '2019-01-03T17:12:02.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T17:11:37.000',
#   'dropoff_datetime': '2019-01-03T18:08:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-03T17:10:42.000',
#   'dropoff_datetime': '2019-01-03T18:01:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-03T17:04:18.000',
#   'dropoff_datetime': '2019-01-03T18:10:01.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-03T19:47:08.000',
#   'dropoff_datetime': '2019-01-03T20:20:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T20:23:39.000',
#   'dropoff_datetime': '2019-01-03T20:59:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T20:16:01.000',
#   'dropoff_datetime': '2019-01-03T20:47:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-03T20:25:39.000',
#   'dropoff_datetime': '2019-01-03T20:59:49.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-03T21:57:38.000',
#   'dropoff_datetime': '2019-01-03T22:28:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-03T13:16:46.000',
#   'dropoff_datetime': '2019-01-03T14:01:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-04T02:39:02.000',
#   'dropoff_datetime': '2019-01-04T03:12:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-04T03:21:21.000',
#   'dropoff_datetime': '2019-01-04T03:52:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-04T03:28:42.000',
#   'dropoff_datetime': '2019-01-04T03:56:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-04T04:35:08.000',
#   'dropoff_datetime': '2019-01-04T05:01:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-04T04:14:27.000',
#   'dropoff_datetime': '2019-01-04T04:45:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-04T04:20:54.000',
#   'dropoff_datetime': '2019-01-04T04:56:43.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-04T04:48:24.000',
#   'dropoff_datetime': '2019-01-04T05:15:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-04T04:48:46.000',
#   'dropoff_datetime': '2019-01-04T05:17:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-04T05:06:21.000',
#   'dropoff_datetime': '2019-01-04T05:49:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
# ...
#   'pickup_datetime': '2019-01-13T13:29:31.000',
#   'dropoff_datetime': '2019-01-13T14:05:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-13T13:59:17.000',
#   'dropoff_datetime': '2019-01-13T14:46:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-13T13:57:25.000',
#   'dropoff_datetime': '2019-01-13T14:38:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-13T14:40:37.000',
#   'dropoff_datetime': '2019-01-13T15:19:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-13T14:29:04.000',
#   'dropoff_datetime': '2019-01-13T15:14:23.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-13T14:10:59.000',
#   'dropoff_datetime': '2019-01-13T14:48:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-13T14:54:13.000',
#   'dropoff_datetime': '2019-01-13T15:31:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-13T14:21:56.000',
#   'dropoff_datetime': '2019-01-13T15:15:39.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-13T14:17:59.000',
#   'dropoff_datetime': '2019-01-13T15:17:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T15:59:42.000',
#   'dropoff_datetime': '2019-01-13T16:42:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T15:45:39.000',
#   'dropoff_datetime': '2019-01-13T16:36:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-13T15:29:43.000',
#   'dropoff_datetime': '2019-01-13T16:13:43.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-13T15:54:13.000',
#   'dropoff_datetime': '2019-01-13T16:43:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-13T15:13:59.000',
#   'dropoff_datetime': '2019-01-13T16:10:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-13T15:23:13.000',
#   'dropoff_datetime': '2019-01-13T16:07:13.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-13T15:26:04.000',
#   'dropoff_datetime': '2019-01-13T16:04:15.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-13T15:35:26.000',
#   'dropoff_datetime': '2019-01-13T16:25:32.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-13T15:28:18.000',
#   'dropoff_datetime': '2019-01-13T16:11:39.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T16:28:27.000',
#   'dropoff_datetime': '2019-01-13T17:12:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-13T16:05:03.000',
#   'dropoff_datetime': '2019-01-13T16:44:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-13T16:55:28.000',
#   'dropoff_datetime': '2019-01-13T17:47:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-13T16:48:02.000',
#   'dropoff_datetime': '2019-01-13T17:29:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-13T16:17:23.000',
#   'dropoff_datetime': '2019-01-13T17:05:23.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-13T16:08:49.000',
#   'dropoff_datetime': '2019-01-13T16:54:39.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T17:01:43.000',
#   'dropoff_datetime': '2019-01-13T17:50:12.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-13T17:51:01.000',
#   'dropoff_datetime': '2019-01-13T18:33:07.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-13T17:47:37.000',
#   'dropoff_datetime': '2019-01-13T18:28:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T18:58:41.000',
#   'dropoff_datetime': '2019-01-13T19:30:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-13T18:11:47.000',
#   'dropoff_datetime': '2019-01-13T18:48:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-13T18:46:44.000',
#   'dropoff_datetime': '2019-01-13T19:22:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-13T19:14:53.000',
#   'dropoff_datetime': '2019-01-13T19:51:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-13T19:57:37.000',
#   'dropoff_datetime': '2019-01-13T20:31:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-13T20:38:38.000',
#   'dropoff_datetime': '2019-01-13T21:16:29.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-14T03:55:11.000',
#   'dropoff_datetime': '2019-01-14T04:27:42.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-14T04:17:13.000',
#   'dropoff_datetime': '2019-01-14T04:45:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T05:02:50.000',
#   'dropoff_datetime': '2019-01-14T05:31:38.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-14T06:34:56.000',
#   'dropoff_datetime': '2019-01-14T07:17:58.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T07:17:13.000',
#   'dropoff_datetime': '2019-01-14T07:59:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-14T07:50:22.000',
#   'dropoff_datetime': '2019-01-14T08:24:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-14T07:06:05.000',
#   'dropoff_datetime': '2019-01-14T07:43:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02865',
#   'pickup_datetime': '2019-01-14T08:19:56.000',
#   'dropoff_datetime': '2019-01-14T09:02:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-14T08:11:55.000',
#   'dropoff_datetime': '2019-01-14T09:00:07.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T09:23:06.000',
#   'dropoff_datetime': '2019-01-14T10:22:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T10:50:51.000',
#   'dropoff_datetime': '2019-01-14T11:27:10.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-14T10:02:34.000',
#   'dropoff_datetime': '2019-01-14T10:47:50.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-14T10:00:22.000',
#   'dropoff_datetime': '2019-01-14T10:44:59.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T11:30:30.000',
#   'dropoff_datetime': '2019-01-14T12:14:01.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-14T11:15:04.000',
#   'dropoff_datetime': '2019-01-14T11:50:49.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-14T11:37:24.000',
#   'dropoff_datetime': '2019-01-14T12:29:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-14T11:28:19.000',
#   'dropoff_datetime': '2019-01-14T12:07:52.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T12:56:08.000',
#   'dropoff_datetime': '2019-01-14T13:40:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T12:20:03.000',
#   'dropoff_datetime': '2019-01-14T13:10:05.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T12:40:39.000',
#   'dropoff_datetime': '2019-01-14T13:30:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T12:35:55.000',
#   'dropoff_datetime': '2019-01-14T13:22:01.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-14T12:17:11.000',
#   'dropoff_datetime': '2019-01-14T13:00:24.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-14T12:25:04.000',
#   'dropoff_datetime': '2019-01-14T13:12:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02870',
#   'pickup_datetime': '2019-01-14T12:08:45.000',
#   'dropoff_datetime': '2019-01-14T12:47:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-14T12:29:21.000',
#   'dropoff_datetime': '2019-01-14T13:10:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-14T12:43:13.000',
#   'dropoff_datetime': '2019-01-14T13:24:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-14T12:43:54.000',
#   'dropoff_datetime': '2019-01-14T13:18:44.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-14T12:19:52.000',
#   'dropoff_datetime': '2019-01-14T13:08:54.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T13:31:03.000',
#   'dropoff_datetime': '2019-01-14T14:10:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02512',
#   'pickup_datetime': '2019-01-14T13:18:35.000',
#   'dropoff_datetime': '2019-01-14T14:10:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-14T13:28:51.000',
#   'dropoff_datetime': '2019-01-14T14:14:25.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T13:19:35.000',
#   'dropoff_datetime': '2019-01-14T14:11:35.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T13:11:16.000',
#   'dropoff_datetime': '2019-01-14T13:54:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-14T13:04:20.000',
#   'dropoff_datetime': '2019-01-14T13:45:50.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-14T13:15:50.000',
#   'dropoff_datetime': '2019-01-14T14:13:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-14T13:42:37.000',
#   'dropoff_datetime': '2019-01-14T14:19:11.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-14T13:43:17.000',
#   'dropoff_datetime': '2019-01-14T14:49:25.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-14T13:00:04.000',
#   'dropoff_datetime': '2019-01-14T13:46:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T14:43:05.000',
#   'dropoff_datetime': '2019-01-14T15:31:14.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T14:03:10.000',
#   'dropoff_datetime': '2019-01-14T15:36:45.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T14:35:15.000',
#   'dropoff_datetime': '2019-01-14T15:25:05.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-14T14:37:38.000',
#   'dropoff_datetime': '2019-01-14T15:46:31.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-14T14:10:18.000',
#   'dropoff_datetime': '2019-01-14T15:05:18.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-14T14:42:49.000',
#   'dropoff_datetime': '2019-01-14T15:23:04.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-14T14:54:21.000',
#   'dropoff_datetime': '2019-01-14T15:51:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02880',
#   'pickup_datetime': '2019-01-14T14:59:06.000',
#   'dropoff_datetime': '2019-01-14T15:38:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-14T14:49:24.000',
#   'dropoff_datetime': '2019-01-14T15:35:07.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-14T14:14:35.000',
#   'dropoff_datetime': '2019-01-14T14:58:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T15:50:43.000',
#   'dropoff_datetime': '2019-01-14T16:40:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T15:50:37.000',
#   'dropoff_datetime': '2019-01-14T16:52:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T15:43:41.000',
#   'dropoff_datetime': '2019-01-14T16:40:56.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-14T15:57:58.000',
#   'dropoff_datetime': '2019-01-14T16:45:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-14T15:32:08.000',
#   'dropoff_datetime': '2019-01-14T16:22:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-14T15:04:35.000',
#   'dropoff_datetime': '2019-01-14T16:03:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T16:03:28.000',
#   'dropoff_datetime': '2019-01-14T16:53:03.000',
#   'pulocationid': '162',
#   'dolocationid': '1'}]

# %%
parser.parse(data[0]['dropoff_datetime']) - parser.parse(data[0]['pickup_datetime'])
# Out:
# datetime.timedelta(seconds=2775)

# %%
# write parameters here for shared FHV
parameter = {'pulocationid':162, 'dolocationid':1, 'sr_flag':1}

# %%
# get shared FHV travel time from one observation for above O-D pair
url = "https://data.cityofnewyork.us/resource/u6nh-b56h.json"
r = requests.get(url = url, params=parameter)
dataShared = r.json()
len(data)
# Out:
# 1000

# %%
parser.parse(dataShared[0]['dropoff_datetime']) - parser.parse(dataShared[0]['pickup_datetime'])
# Out:
# datetime.timedelta(seconds=2775)

# %% [markdown]
# ### Task 2. Write the function for getting FHV and Shared FHV times for 50 sample O-D pairs.
#
# #### Hint: see above that the returned FHV/shared FHV data has column names 'pickup_datetime' and 'dropoff_datetime' instead of 'tpep_pickup_datetime' and 'tpep_dropoff_datetime' used in the functions above. So make sure to change these names when writing the code below
#
#
# Also make necessary filtering to remove outliers. Remember, in this data, just travel times are available, so we don't need any other variable outlier filtering.

# %%
# sample points
df = pd.read_csv('https://raw.githubusercontent.com/CUSP2020PUI/Data/master/samplePoints.csv')
sample = df.sample(50, random_state=2020)
sample.head()
# Out:
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 109         110  -74.128342   40.545780          254   -73.858948    40.882157
# 50           51  -73.828264   40.873973           92   -73.828859    40.761102
# 165         166  -73.961764   40.809457          234   -73.990458    40.740337
# 206         207  -73.899353   40.763986          248   -73.872289    40.834165
# 194         195  -74.009178   40.675549           68   -73.999917    40.748428

# %%
# write function for getting average FHV and SFHV times
#### hint: function will essentially be the same as for FHV except for the change in the request parameters and returning 
def FHVtimes(df):
    FHV_times = []
    SFHV_times = []
    for index, row in df.iterrows():
        parameters = {'pulocationid':int(row['LocationID']), 'dolocationid':int(row['LocationID2'])}
        url = "https://data.cityofnewyork.us/resource/u6nh-b56h.json"
        r = requests.get(url = url, params=parameters)
        data = r.json()
        Travel_time_sh = []
        Travel_time = []
        for obs in data:
            try:
                # sfhv
                if obs["sr_flag"] == '1':
                    time = parser.parse(obs['dropoff_datetime']) - parser.parse(obs['pickup_datetime'])
                    time = time.total_seconds()
                    if (time < 6000 and time > 60): 
                        Travel_time_sh.append(time)
            except:
                pass
            try:
                # fhv
                time = parser.parse(obs['dropoff_datetime']) - parser.parse(obs['pickup_datetime'])
                time = time.total_seconds()
                if (time < 6000 and time > 60): 
                    Travel_time.append(time)
            except:
                pass
            
        FHV_times.append(np.mean(Travel_time))
        SFHV_times.append(np.mean(Travel_time_sh))
    
    # code here
    
    
    return (FHV_times,SFHV_times)

# %%
## requests from API (call the above function)

FHV_times , SFHV_times = FHVtimes(df)
print(FHV_times)
# Out:
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# /Users/siyumiao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/siyumiao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 6
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 9
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 7
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 6
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 7
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 6
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 5
# ^^^ 6
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 8
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 6
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 4
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 6
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# ...
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 6
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 22
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 7
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 9
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 9
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 6
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 6
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 10
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 7
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 6
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 7
# ^^^ 2
# ^^^ 6
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 7
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 7
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 8
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 9
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# [3313.9736842105262, nan, 2804.0, 1032.516, 3931.25, 2674.6666666666665, 1401.0838815789473, nan, 2588.3571428571427, 2497.267441860465, 1047.7307692307693, nan, nan, 2413.2619047619046, 1611.0, 1063.0, 2389.6666666666665, 2352.277777777778, nan, 2863.3333333333335, 1157.0849342770475, 2502.093567251462, 1765.0108108108109, 1728.5454545454545, 1580.2693409742121, 1810.2067039106146, nan, 2320.9473684210525, 2399.2631578947367, 1059.5, nan, 1050.68, 787.1909909909909, 2691.0, 1262.8391959798994, 1742.624852071006, 2466.5170731707317, 2951.5, 3725.818181818182, 2452.1666666666665, 2465.4554554554556, 1162.8251121076232, 2405.4375, nan, 2215.8333333333335, nan, 1077.5515515515515, 1127.896, 607.553, 2211.03125, 1431.289156626506, 1782.5, 1175.7333333333333, 2084.4, 3268.266666666667, nan, 2674.217391304348, nan, 1628.4285714285713, 1698.5, 1944.6923076923076, 2815.722222222222, 2961.5, 2800.9, 1749.401913875598, 836.9219143576826, 2710.5416666666665, 2972.48, 2195.176470588235, 2233.0, 2023.0, 1905.25, 2399.32, 1499.7866972477063, 2649.019230769231, 2593.0, 3392.3835616438355, 2449.627450980392, 2080.0, 1605.111111111111, 2252.3880597014927, 1667.3545454545454, 1477.4444444444443, 1587.0449438202247, 2797.5, 2848.294117647059, 2537.75, 2415.201550387597, 3217.3214285714284, 2354.0227272727275, 2467.4418604651164, 2289.7948717948716, 2551.6470588235293, nan, 2096.4598540145985, nan, nan, 2628.0833333333335, 829.0575539568346, 2088.725352112676, 731.27, 2779.1052631578946, nan, nan, nan, 1061.5897435897436, 1443.635, 4136.0, 3936.0, nan, nan, 3265.0, 1864.9666666666667, 1158.6506189821182, 2363.08, 2858.6, 3729.875, 2341.6666666666665, nan, 2578.0, 2125.830985915493, 1978.0588235294117, 3467.5, nan, 2665.0, 2535.5, 2423.8, 1344.9661016949153, 1636.3968253968253, 2550.6, 2372.470588235294, 1823.0250250250251, 3825.5, 2142.9666666666667, 821.755868544601, 2669.842105263158, 2154.9915966386557, 1296.738, nan, 1538.9354838709678, 2974.5102040816328, 2645.866666666667, 2459.4406779661017, 2609.6753246753246, 868.1511511511511, nan, 1541.4705882352941, 1251.763, 2879.0, 1400.9015817223199, 737.8890063424947, 2592.6190476190477, 1175.9634146341464, nan, 3383.0169491525426, nan, 1896.0, 1259.0890890890892, 1243.9180327868853, 1527.2910052910054, 2228.5898089171974, 815.9018036072144, 2227.8939393939395, 533.7587587587587, 2505.5, 1890.9441930618402, 2357.8214285714284, 1471.3139534883721, 2333.8571428571427, 2673.4545454545455, 1738.3225806451612, nan, 2105.0, nan, 2890.266666666667, 3950.5, 2089.8, 3908.0, 1813.0444444444445, 2162.0454545454545, 2520.184210526316, 1185.765163297045, 988.6851851851852, nan, 2606.0, 1910.892857142857, 2050.4, 2308.9, 2327.0, 1932.2884615384614, 1305.4468085106382, 1930.5, 2261.32, nan, 1640.84375, 2091.56, 2691.974358974359, 2390.095238095238, nan, 2357.0, 1745.969696969697, 1829.3333333333333, 2069.943396226415, nan, 2976.3333333333335, 3562.8529411764707, 1511.0, 1454.125, 643.081, 3254.3684210526317, 936.465, 432.1470588235294, nan, 3062.4, 1852.0729927007299, 2923.5, 2405.277777777778, 1297.2553191489362, 2407.0714285714284, 1431.2631578947369, 2027.4545454545455, 2319.176470588235, 1668.3333333333333, 2037.375, 1535.8333333333333, 1115.7685185185185, 1068.8168168168168, 2572.6666666666665, 631.736, nan, 1379.323, 2571.5625, 668.879, nan, 2826.5, 2879.1052631578946, 3322.8703703703704, nan, nan, 3994.3333333333335, 2918.133333333333, 921.833, 1802.5333333333333, 2798.5, 2200.0625, 3028.1428571428573, 3328.25, 2501.8285714285716, 2307.4117647058824, 558.0280280280281, 2540.1428571428573, 1303.025641025641, nan, 2300.0, 1524.445652173913, 2162.0, 1752.0, 2690.308510638298, 2614.4375, 1688.4285714285713, 1988.3529411764705, 3201.0285714285715, 3508.0]

# %%
# create new columns in the above 'sample' dataframe named 'FHV time' and 'SFHV time' with above retrieved times
sample['FHV_times'], sample['SFHV_times'] = FHVtimes(sample)
sample
# Out:
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 6
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 8
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 7
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 4
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 4
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 5
# ^^^ 6
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 5
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 10
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 6
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 5
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 4
# ^^^ 2
# ^^^ 4
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 6
# ^^^ 3
# ^^^ 2
# ^^^ 4
# ^^^ 5
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 5
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 4
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 6
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 5
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 5
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 4
# ^^^ 1
# 1111111112323
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 2
# ^^^ 2
# ^^^ 3
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
# ^^^ 1
# 1111111112323
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  \
# 109         110  -74.128342   40.545780          254   -73.858948
# 50           51  -73.828264   40.873973           92   -73.828859
# 165         166  -73.961764   40.809457          234   -73.990458
# 206         207  -73.899353   40.763986          248   -73.872289
# 194         195  -74.009178   40.675549           68   -73.999917
# 250         251  -74.125348   40.616880          114   -73.997380
# 70           71  -73.937966   40.644288          118   -74.132979
# 138         139  -73.744234   40.677098          202   -73.949952
# 75           76  -73.876821   40.660935          240   -73.881978
# 164         165  -73.956825   40.620924          258   -73.855767
# 240         241  -73.895620   40.876512          205   -73.763146
# 144         145  -73.948891   40.745379           80   -73.936793
# 224         225  -73.931888   40.688168          111   -73.990235
# 104         103  -74.019073   40.688784          215   -73.790964
# 34           35  -73.910258   40.664003          124   -73.844919
# 245         246  -74.004015   40.753309          197   -73.830924
# 221         222  -73.882413   40.647527          131   -73.776101
# 87           88  -74.011515   40.703358           35   -73.910258
# 162         163  -73.977569   40.764421           78   -73.885522
# 61           62  -73.948789   40.666540          141   -73.959635
# 123         124  -73.844919   40.658248          103   -74.040771
# 93           94  -73.899536   40.858155          204   -74.207826
# 5             6  -74.071771   40.600324          242   -73.850671
# 58           59  -73.894986   40.838550           82   -73.877118
# 158         159  -73.912849   40.818260          263   -73.951010
# 31           32  -73.864901   40.864002          169   -73.905122
# 101         102  -73.875736   40.703546          165   -73.956825
# 25           26  -73.988661   40.630950          150   -73.943629
# 241         242  -73.850671   40.846783           81   -73.836643
# 180         181  -73.981414   40.670374          152   -73.953782
# 242         243  -73.932831   40.857108          192   -73.815229
# 106         107  -73.984052   40.736824          142   -73.981532
# 214         215  -73.790964   40.694428          177   -73.913632
# 35           36  -73.917711   40.700522           33   -73.995250
# 220         221  -74.073704   40.618769          133   -73.976199
# 15           16  -73.773422   40.762738           59   -73.894986
# 103         103  -74.040771   40.698769           48   -73.989845
# 108         109  -74.150890   40.551863           73   -73.807294
# 124         125  -74.007486   40.726290           44   -74.233534
# 256         257  -73.977982   40.653612          156   -74.167235
# 43           44  -74.233534   40.525495           83   -73.892173
# 259         260  -73.906306   40.744235          190   -73.968914
# 23           24  -73.965480   40.801970          250   -73.848641
# 18           19  -73.726655   40.735487          103   -74.045288
# 192         193  -73.941997   40.760314           62   -73.948789
# 247         248  -73.872289   40.834165          231   -74.007880
# 27           28  -73.808729   40.711596          100   -73.988787
# 151         152  -73.953782   40.817975           14   -74.029892
# 115         116  -73.948522   40.827013          122   -73.761137
# 51           52  -73.996724   40.686651          193   -73.941997
#
#      lat_dropoff    FHV_times   SFHV_times
# 109    40.882157          NaN          NaN
# 50     40.761102  1431.289157  1493.700000
# 165    40.740337  1890.944193  2217.561224
# 206    40.834165  1511.000000          NaN
# 194    40.748428  1640.843750  1828.200000
# 250    40.728340  2540.142857          NaN
# 70     40.586555  2023.000000          NaN
# 138    40.761900          NaN          NaN
# 75     40.894599  2593.000000          NaN
# 164    40.688721  2505.500000  2552.625000
# 240    40.691201  2918.133333          NaN
# 144    40.715370   868.151151  1086.326241
# 224    40.652137  1535.833333  2059.000000
# 104    40.694428          NaN          NaN
# 34     40.658248  1262.839196  1479.818182
# 245    40.694542  3028.142857  2856.833333
# 221    40.720655  2319.176471  1905.000000
# 87     40.664003  2415.201550  2459.250000
# 162    40.844960  2227.893939  2637.000000
# 61     40.766948  2815.722222  2655.181818
# 123    40.698769          NaN          NaN
# 93     40.540334          NaN          NaN
# 5      40.846783  2674.666667          NaN
# 58     40.739496  1628.428571  1791.333333
# 158    40.778766  1243.918033  1373.955224
# 31     40.849058  1050.680000  1323.537634
# 101    40.620924  2779.105263  2654.000000
# 25     40.580473  1810.206704  1952.137500
# 241    40.880935   921.833000  1140.143791
# 180    40.817975  2520.184211  2698.769231
# 242    40.743751  1802.533333  2151.333333
# 106    40.773633  1443.635000  1625.223404
# 214    40.676644  1852.072993  2142.875000
# 35     40.695798  1742.624852  2008.919463
# 220    40.640590  2027.454545  1940.000000
# 15     40.838550  1063.000000          NaN
# 103    40.762253          NaN          NaN
# 108    40.754109  3936.000000          NaN
# 124    40.525495  2665.000000          NaN
# 256    40.631308  1752.000000          NaN
# 43     40.738324          NaN          NaN
# 259    40.661622  1688.428571          NaN
# 23     40.832102  1728.545455  1962.375000
# 18     40.689860          NaN          NaN
# 192    40.666540  2261.320000  2377.250000
# 247    40.717773  2501.828571  2750.400000
# 27     40.753513  2320.947368  3306.000000
# 151    40.624835  2592.619048  3011.600000
# 115    40.710639  2858.600000  2362.500000
# 51     40.760314  1782.500000          NaN

# %% [markdown]
# ### Task 3: Comparison of times for FHV and shared FHV

# %%
## check number of 'Nan' values (if any) retrieved from travel times
sample.isna().sum()
# Out:
# LocationID      0
# lon_pickup      0
# lat_pickup      0
# LocationID2     0
# lon_dropoff     0
# lat_dropoff     0
# FHV_times       8
# SFHV_times     20
# TLC_avgtime    19
# dtype: int64

# %%
# remove the rows if any of the retrieved FHV or shared FHV times has 'Nan'
sample.dropna()
# Out:
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  \
# 50           51  -73.828264   40.873973           92   -73.828859
# 165         166  -73.961764   40.809457          234   -73.990458
# 194         195  -74.009178   40.675549           68   -73.999917
# 164         165  -73.956825   40.620924          258   -73.855767
# 144         145  -73.948891   40.745379           80   -73.936793
# 34           35  -73.910258   40.664003          124   -73.844919
# 245         246  -74.004015   40.753309          197   -73.830924
# 221         222  -73.882413   40.647527          131   -73.776101
# 87           88  -74.011515   40.703358           35   -73.910258
# 162         163  -73.977569   40.764421           78   -73.885522
# 61           62  -73.948789   40.666540          141   -73.959635
# 158         159  -73.912849   40.818260          263   -73.951010
# 31           32  -73.864901   40.864002          169   -73.905122
# 101         102  -73.875736   40.703546          165   -73.956825
# 25           26  -73.988661   40.630950          150   -73.943629
# 241         242  -73.850671   40.846783           81   -73.836643
# 180         181  -73.981414   40.670374          152   -73.953782
# 106         107  -73.984052   40.736824          142   -73.981532
# 214         215  -73.790964   40.694428          177   -73.913632
# 35           36  -73.917711   40.700522           33   -73.995250
# 23           24  -73.965480   40.801970          250   -73.848641
# 192         193  -73.941997   40.760314           62   -73.948789
# 247         248  -73.872289   40.834165          231   -74.007880
# 27           28  -73.808729   40.711596          100   -73.988787
# 151         152  -73.953782   40.817975           14   -74.029892
# 115         116  -73.948522   40.827013          122   -73.761137
#
#      lat_dropoff    FHV_times   SFHV_times  TLC_avgtime
# 50     40.761102  1431.289157  1493.700000  1398.000000
# 165    40.740337  1890.944193  2217.561224  1834.531062
# 194    40.748428  1640.843750  1828.200000  2149.000000
# 164    40.688721  2505.500000  2552.625000  2622.000000
# 144    40.715370   868.151151  1086.326241   793.379822
# 34     40.658248  1262.839196  1479.818182  1435.750000
# 245    40.694542  3028.142857  2856.833333  2608.927711
# 221    40.720655  2319.176471  1905.000000  1703.000000
# 87     40.664003  2415.201550  2459.250000  2744.420000
# 162    40.844960  2227.893939  2637.000000  1990.569892
# 61     40.766948  2815.722222  2655.181818  2914.750000
# 158    40.778766  1243.918033  1373.955224  1234.857143
# 31     40.849058  1050.680000  1323.537634  1674.466667
# 101    40.620924  2779.105263  2654.000000  2252.500000
# 25     40.580473  1810.206704  1952.137500  2114.281250
# 241    40.880935   921.833000  1140.143791  1091.036364
# 180    40.817975  2520.184211  2698.769231  2529.794872
# 106    40.773633  1443.635000  1625.223404  1216.478478
# 214    40.676644  1852.072993  2142.875000  1930.000000
# 35     40.695798  1742.624852  2008.919463  1345.080645
# 23     40.832102  1728.545455  1962.375000  2015.424242
# 192    40.666540  2261.320000  2377.250000  2230.333333
# 247    40.717773  2501.828571  2750.400000  3477.666667
# 27     40.753513  2320.947368  3306.000000  2395.705263
# 151    40.624835  2592.619048  3011.600000  2543.900000
# 115    40.710639  2858.600000  2362.500000  2046.000000

# %%
# make scatter plot comparing FHV times with shared FHV times for the 50 sample O-D pairs
# add a FHV=SFHV baseline to see if most of the points are above (FHV time>SFHV time) or below (FHV time<SFHV time)
from matplotlib import pyplot as plt
plt.plot(sample.FHV_times, sample.SFHV_times, 'o')
plt.plot([1000, 3500], [1000, 3500], color='gray', label='FHV=SFHV') # plots line y = x
plt.show()
# hint: use plt.plot(var1, var2, 'o') for scatter plots between two variables var1 and var2 of interest

# %% [markdown]
# ## Extra credit task- Using one other API : geocoding
# Geocoding referes to converting textual addresses into lat-long. Useful in getting a precise location of a place

# %% [markdown]
# we'll use HereAPI again for geocoding. Same API key as before will work. The endpoint for geocoding API is https://geocode.search.hereapi.com/v1/geocode
# Many other companies also provide geocoding API services (eg. Google)
#
# To specify an address, we use the 'q' parameter in the endpoint. For example, if we want to get lat-long for '5 Rue Daunou, 75000 Paris, France', we'll use the following endpoint:
#
# https://geocode.search.hereapi.com/v1/geocode?q=5+Rue+Daunou%2C+75000+Paris%2C+France&apiKey={}
#
# Essentially, we write the addresses as a query with spaces being replaced by '+' and commas being repalced by '%2C'

# %%
## try out a geocode request for a random address. Remember to be precise in specifying the address to remove any ambiguity

# API key
key = "bc27E14ltgyOh7tZXeuKEOWSiF-1q51gRkIaiRV3mhE"

# API endpoint with query as your address
q = '5 Rue Daunou, 75000 Paris, France'
q = q.replace(" ", '+')
q = q.replace(",", '%2C')
url = "https://geocode.search.hereapi.com/v1/geocode?q={}&apiKey={}".format(q, key)

data = urllib.urlopen(url).read().decode('utf-8')
data = json.loads(data)
data


#data = urllib.urlopen(url).read().decode('utf-8')
#data = json.loads(data)
#data
# Out:
# {'items': [{'title': '5 Rue Daunou, 75002 Paris, France',
#    'id': 'here:af:streetsection:NQHc13Wvqj0xq9jew7-8sC:CggIBCCi-9SPARABGgE1',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'PA',
#    'address': {'label': '5 Rue Daunou, 75002 Paris, France',
#     'countryCode': 'FRA',
#     'countryName': 'France',
#     'stateCode': 'IDF',
#     'state': 'Île-de-France',
#     'county': 'Paris',
#     'city': 'Paris',
#     'district': '2e Arrondissement',
#     'street': 'Rue Daunou',
#     'postalCode': '75002',
#     'houseNumber': '5'},
#    'position': {'lat': 48.86926, 'lng': 2.3321},
#    'access': [{'lat': 48.86931, 'lng': 2.33215}],
#    'mapView': {'west': 2.33073,
#     'south': 48.86836,
#     'east': 2.33347,
#     'north': 48.87016},
#    'scoring': {'queryScore': 0.97,
#     'fieldScore': {'country': 1.0,
#      'city': 1.0,
#      'streets': [1.0],
#      'houseNumber': 1.0,
#      'postalCode': 0.82}}}]}

# %%
## get latitude and longitude from returned json request

la = data['items'][0]['position']['lat']
lng = data['items'][0]['position']['lng']

# %%
la
# Out:
# 48.86926

# %%
lng
# Out:
# 2.3321
